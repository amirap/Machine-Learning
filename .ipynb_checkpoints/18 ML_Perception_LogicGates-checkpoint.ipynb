# %% [markdown]
# # Project: Perceptron Logic Gates
#
# In this project, we will use perceptrons to model the fundamental building blocks of computers — logic gates.

# %% [markdown]
# ## Part 1: Creating and visualizing AND Data

# %%
import numpy as np

# %%
from IPython.display import Image
Image('/Users/Amir/PythonProjects/Machine-Learning/LogicGates.jpeg')

# %%
# Create input and output
# four possible inputs to the AND gate
data = [[0, 0], [0, 1], [1, 0], [1, 1]]
#Labels for AND
labels = [0, 0, 0, 1]

# %%
# visualize the data and labels
import matplotlib.pyplot as plt
plt.scatter([point[0] for point in data], [point[1] for point in data], c=labels)
plt.show()
fig()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-91073253fcb0> in <module>
#       3 plt.scatter([point[0] for point in data], [point[1] for point in data], c=labels)
#       4 plt.show()
# ----> 5 fig()
#
# NameError: name 'fig' is not defined

# %% [markdown]
# ## Part 2: Building the Perceptron

# %% [markdown]
# ## Part 3:

# %% [markdown]
# ## Part 4:
